# %%
import pandas as pd

# %%
import numpy as np
import pandas as pd
import seaborn as sns # For pairplots and heatmaps
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('hourly_finalData.csv')

# %%
#del(data['Unnamed: 0'])

data.corr(method="pearson")
# Out:
#               chargingtime  occupation  Unnamed: 0_y     TT_TU     RF_TU  \
# chargingtime      1.000000    1.000000     -0.034292 -0.006985 -0.014731
# occupation        1.000000    1.000000     -0.034292 -0.006985 -0.014731
# Unnamed: 0_y     -0.034292   -0.034292      1.000000 -0.046378  0.046573
# TT_TU            -0.006985   -0.006985     -0.046378  1.000000 -0.507163
# RF_TU            -0.014731   -0.014731      0.046573 -0.507163  1.000000
#   R1             -0.001850   -0.001850     -0.062804  0.091702 -0.068254
# RS_IND           -0.001870   -0.001870     -0.062882  0.091088 -0.067320
# hour              0.184231    0.184231      0.000295  0.122639 -0.199055
# dayofweek        -0.025492   -0.025492      0.001186  0.002207  0.008981
# quarter           0.007474    0.007474     -0.087820  0.211313  0.159212
# month             0.008094    0.008094     -0.071439  0.208444  0.156046
# year             -0.034003   -0.034003      0.923175 -0.122469 -0.017171
# ...

# %%
display_correlation(data)
# Out:
#               chargingtime  occupation  Unnamed: 0_y     TT_TU     RF_TU  \
# chargingtime      1.000000    1.000000     -0.034029 -0.014792 -0.014427
# occupation        1.000000    1.000000     -0.034029 -0.014792 -0.014427
# Unnamed: 0_y     -0.034029   -0.034029      1.000000 -0.047479  0.067510
# TT_TU            -0.014792   -0.014792     -0.047479  1.000000 -0.431968
# RF_TU            -0.014427   -0.014427      0.067510 -0.431968  1.000000
#   R1              0.001418    0.001418     -0.040896 -0.004350  0.261253
# RS_IND           -0.004733   -0.004733     -0.038094 -0.061954  0.286108
# hour              0.177603    0.177603      0.000295  0.115779 -0.211376
# dayofweek        -0.015016   -0.015016      0.001181  0.002893  0.003565
# quarter           0.006088    0.006088     -0.091797  0.217930  0.161910
# month             0.006144    0.006144     -0.073154  0.206293  0.150541
# year             -0.034973   -0.034973      0.932229 -0.112203  0.000098
# ...

# %%
def display_correlation(df):
    r = df.corr(method="spearman")
    plt.figure(figsize=(20,2))
    heatmap = sns.heatmap(df.corr(), vmin=-1, 
                      vmax=1, annot=True)
    plt.title("Spearman Correlation")
    plt.show()
    return(r)

# %%
df = data.copy()
#del(data['occupation'])
#del(data['categorieOcc'])
#del(data['binaryOcc'])

#del(data['Unnamed: 0'])
#del(data['chargingstart'])

# %% [markdown]
# ## Correlation 1VSALL

# %%
df = data[(data['year']>=2020)]
data.corr()
# Out:
#               Unnamed: 0  Unnamed: 0.1  Unnamed: 0_x  chargingtime  \
# Unnamed: 0      1.000000      1.000000      1.000000      0.210924
# Unnamed: 0.1    1.000000      1.000000      1.000000      0.210924
# Unnamed: 0_x    1.000000      1.000000      1.000000      0.210924
# chargingtime    0.210924      0.210924      0.210924      1.000000
# occupation      0.210924      0.210924      0.210924      1.000000
# Unnamed: 0_y    1.000000      1.000000      1.000000      0.210924
# TT_TU           0.010254      0.010254      0.010254      0.014271
# RF_TU          -0.019467     -0.019467     -0.019467     -0.034533
#   R1           -0.065392     -0.065392     -0.065392     -0.023370
# RS_IND         -0.065301     -0.065301     -0.065301     -0.023284
# hour            0.000171      0.000171      0.000171      0.057419
# dayofweek      -0.001329     -0.001329     -0.001329     -0.066149
# quarter         0.052536      0.052536      0.052536      0.039919
# ...

# %% [markdown]
# ## Correlation 1VS1

# %%
#Principle Component Analysis PCA
from sklearn.decomposition import PCA 
X = data

pca = PCA(n_components=1)
pca.fit(X)
#pca.components_
Z = pca.transform(X)
Z.shape
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_220/1757568478.py in <module>
#       4
#       5 pca = PCA(n_components=1)
# ----> 6 pca.fit(X)
#       7 #pca.components_
#       8 Z = pca.transform(X)
#
# /opt/conda/lib/python3.9/site-packages/sklearn/decomposition/_pca.py in fit(self, X, y)
#     380             Returns the instance itself.
#     381         """
# --> 382         self._fit(X)
#     383         return self
#     384
#
# /opt/conda/lib/python3.9/site-packages/sklearn/decomposition/_pca.py in _fit(self, X)
#     428             )
#     429
# --> 430         X = self._validate_data(
#     431             X, dtype=[np.float64, np.float32], ensure_2d=True, copy=self.copy
#     432         )
#
# /opt/conda/lib/python3.9/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
# ...

# %%
df['AllInOne'] = Z

# %%
df.corr()
# Out:
#               Unnamed: 0  Unnamed: 0.1  Unnamed: 0_x  chargingtime  \
# Unnamed: 0      1.000000      1.000000      1.000000      0.210924
# Unnamed: 0.1    1.000000      1.000000      1.000000      0.210924
# Unnamed: 0_x    1.000000      1.000000      1.000000      0.210924
# chargingtime    0.210924      0.210924      0.210924      1.000000
# occupation      0.210924      0.210924      0.210924      1.000000
# Unnamed: 0_y    1.000000      1.000000      1.000000      0.210924
# TT_TU           0.010254      0.010254      0.010254      0.014271
# RF_TU          -0.019467     -0.019467     -0.019467     -0.034533
#   R1           -0.065392     -0.065392     -0.065392     -0.023370
# RS_IND         -0.065301     -0.065301     -0.065301     -0.023284
# hour            0.000171      0.000171      0.000171      0.057419
# dayofweek      -0.001329     -0.001329     -0.001329     -0.066149
# quarter         0.052536      0.052536      0.052536      0.039919
# ...

# %% [markdown]
# ## 1VSSelf

# %%
#source = https://www.youtube.com/watch?v=y8opUEd05Dg&ab_channel=ritvikmath
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
acf_plot = plot_acf(data.occupation, lags=100)

# %%
pacf_plot = plot_pacf(data.occupation)
# Out:
# /opt/conda/lib/python3.9/site-packages/statsmodels/graphics/tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
df
# Out:
#        Unnamed: 0  Unnamed: 0.1  Unnamed: 0_x              chargingstart  \
# 0               0             0             0  2016-12-14 10:00:00+00:00
# 1               1             1             1  2016-12-14 11:00:00+00:00
# 2               2             2             2  2016-12-14 12:00:00+00:00
# 3               3             3             3  2016-12-14 13:00:00+00:00
# 4               4             4             4  2016-12-14 14:00:00+00:00
# ...           ...           ...           ...                        ...
# 37785       37785         37785         37785  2021-04-06 19:00:00+00:00
# 37786       37786         37786         37786  2021-04-06 20:00:00+00:00
# 37787       37787         37787         37787  2021-04-06 21:00:00+00:00
# 37788       37788         37788         37788  2021-04-06 22:00:00+00:00
# 37789       37789         37789         37789  2021-04-06 23:00:00+00:00
#
#        chargingtime  occupation  Unnamed: 0_y  TT_TU  RF_TU    R1  ...  hour  \
# ...

# %%
data.cov()
# Out:
#               chargingtime  occupation  Unnamed: 0_y        TT_TU  \
# chargingtime   2276.449439   18.970412 -1.033177e+04    -2.283290
# occupation       18.970412    0.158087 -8.609807e+01    -0.019027
# Unnamed: 0_y -10331.767979  -86.098066  3.987448e+07 -2006.365160
# TT_TU            -2.283290   -0.019027 -2.006365e+03    46.936039
# RF_TU           -11.374041   -0.094784  4.759303e+03   -56.229582
#   R1             -6.431094   -0.053592 -2.890141e+04    45.784302
# RS_IND           -6.504665   -0.054206 -2.894273e+04    45.485990
# hour             60.850400    0.507087  1.291512e+01     5.816380
# dayofweek        -2.433277   -0.020277  1.498286e+01     0.030256
# quarter           0.426970    0.003558 -6.640088e+02     1.733444
# month             1.427401    0.011895 -1.667494e+03     5.278655
# year             -1.303510   -0.010863  4.683777e+03    -0.674133
# dayofyear        42.790215    0.356585 -4.917311e+04   162.901431
# ...

# %%
data.corr(method='spearman')
# Out:
#               chargingtime  occupation  Unnamed: 0_y     TT_TU     RF_TU  \
# chargingtime      1.000000    1.000000     -0.034029 -0.014792 -0.014427
# occupation        1.000000    1.000000     -0.034029 -0.014792 -0.014427
# Unnamed: 0_y     -0.034029   -0.034029      1.000000 -0.047479  0.067510
# TT_TU            -0.014792   -0.014792     -0.047479  1.000000 -0.431968
# RF_TU            -0.014427   -0.014427      0.067510 -0.431968  1.000000
#   R1              0.001418    0.001418     -0.040896 -0.004350  0.261253
# RS_IND           -0.004733   -0.004733     -0.038094 -0.061954  0.286108
# hour              0.177603    0.177603      0.000295  0.115779 -0.211376
# dayofweek        -0.015016   -0.015016      0.001181  0.002893  0.003565
# quarter           0.006088    0.006088     -0.091797  0.217930  0.161910
# month             0.006144    0.006144     -0.073154  0.206293  0.150541
# year             -0.034973   -0.034973      0.932229 -0.112203  0.000098
# ...

# %%
data
# Out:
#                    chargingstart  chargingtime  occupation  Unnamed: 0_y  \
# 0      2018-10-08 14:00:00+00:00           120    1.000000       33038.0
# 1      2018-10-08 15:00:00+00:00             3    0.025000       33039.0
# 2      2018-10-08 16:00:00+00:00             0    0.000000       33040.0
# 3      2018-10-08 17:00:00+00:00           120    1.000000       33041.0
# 4      2018-10-08 18:00:00+00:00           120    1.000000       33042.0
# ...                          ...           ...         ...           ...
# 21869  2021-04-06 19:00:00+00:00           120    1.000000       54907.0
# 21870  2021-04-06 20:00:00+00:00            99    0.825000       54908.0
# 21871  2021-04-06 21:00:00+00:00           120    1.000000       54909.0
# 21872  2021-04-06 22:00:00+00:00           120    1.000000       54910.0
# 21873  2021-04-06 23:00:00+00:00            98    0.816667       54911.0
#
#        TT_TU  RF_TU    R1  RS_IND                       date  hour  dayofweek  \
# ...

# %%
import pandas as pd
import seaborn as sns

import ppscore as pps
del(data['Unnamed: 0'])

# %%
matrix = pps.matrix(data)

# %%
data
# Out:
#        Unnamed: 0              chargingstart  chargingtime  occupation  \
# 0               0  2018-10-08 14:00:00+00:00           120    1.000000
# 1               1  2018-10-08 15:00:00+00:00             3    0.025000
# 2               2  2018-10-08 16:00:00+00:00             0    0.000000
# 3               3  2018-10-08 17:00:00+00:00           120    1.000000
# 4               4  2018-10-08 18:00:00+00:00           120    1.000000
# ...           ...                        ...           ...         ...
# 21869       21869  2021-04-06 19:00:00+00:00           120    1.000000
# 21870       21870  2021-04-06 20:00:00+00:00            99    0.825000
# 21871       21871  2021-04-06 21:00:00+00:00           120    1.000000
# 21872       21872  2021-04-06 22:00:00+00:00           120    1.000000
# 21873       21873  2021-04-06 23:00:00+00:00            98    0.816667
#
#        Unnamed: 0_y  TT_TU  RF_TU    R1  RS_IND                       date  \
# ...

# %%
pps.score(data, "TT_TU", "occupation")
# Out:
# {'x': 'TT_TU',
#  'y': 'occupation',
#  'ppscore': 0,
#  'case': 'regression',
#  'is_valid_score': True,
#  'metric': 'mean absolute error',
#  'baseline_score': 0.30349666666666664,
#  'model_score': 0.3626946571994366,
#  'model': DecisionTreeRegressor()}
